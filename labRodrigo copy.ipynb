# %%
import pandas as pd
import pylidc as pl
import xml.etree.ElementTree as ET
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Codigo para lembrar apenas

# %%
'''
import sys
# !{sys.executable} -m pip install pyradiomics
'''
# Out:
# '\nimport sys\n!{sys.executable} -m pip install pyradiomics\n'

# %% [markdown]
# # Leitura dos ficheiros

# %%
nodule_counts = pd.read_excel('lidc-idri-nodule-counts-6-23-2015.xlsx', engine='openpyxl')
patient_diagnoses = pd.read_excel('tcia-diagnosis-data-2012-04-20.xls')
dicom_metadata = pd.read_csv('LIDC-IDRI_MetaData.csv')


# Inicializar pylidc para trabalhar com as anotações XML
cases = pl.query(pl.Scan).all()



print(nodule_counts.head())
print(100*"*")
print(patient_diagnoses.head())
print(100*"*")
print(dicom_metadata.head())
print(100*"*")
print(len(cases))
# Out:
#    TCIA Patent ID  Total Number of Nodules*   Number of Nodules >=3mm**  \
# 0  LIDC-IDRI-0001                          4                          1
# 1  LIDC-IDRI-0002                         12                          1
# 2  LIDC-IDRI-0003                          4                          4
# 3  LIDC-IDRI-0004                          4                          1
# 4  LIDC-IDRI-0005                          9                          3
#
#    Number of Nodules <3mm***  Unnamed: 4  \
# 0                          3         NaN
# 1                         11         NaN
# 2                          0         NaN
# 3                          3         NaN
# 4                          6         NaN
#
#                                           Unnamed: 5
# 0                                                NaN
# 1  *total number of lesions that received either ...
# 2  **total number of lesions that received a "nod...
# 3  ***total number of lesions that received a "no...
# 4                                                NaN
# ****************************************************************************************************
#   TCIA Patient ID  \
# 0  LIDC-IDRI-0068
# 1  LIDC-IDRI-0071
# 2  LIDC-IDRI-0072
# 3  LIDC-IDRI-0088
# 4  LIDC-IDRI-0090
#
#    Diagnosis at the Patient Level\n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic\n  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  2
#
#    Diagnosis Method\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response  \
# 0                                                  4
# 1                                                  1
# 2                                                  4
# 3                                                  0
# 4                                                  3
#
#   Primary tumor site for metastatic disease  \
# 0                        Head & Neck Cancer
# 1                              Head & Neck
# 2                               Lung Cancer
# 3                            Uterine Cancer
# 4                                     NSCLC
#
#    Nodule 1\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                3.0
# 1                                                1.0
# 2                                                1.0
# 3                                                0.0
# 4                                                2.0
#
#    Nodule 1\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                4.0
# 1                                                1.0
# 2                                                4.0
# 3                                                0.0
# 4                                                3.0
#
#    Nodule 2\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Nodule 2\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Nodule 3\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Nodule 3\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Nodule 4\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Nodule 4\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Nodule 5\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Nodule 5\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ****************************************************************************************************
#        Subject ID                                          Study UID  \
# 0  LIDC-IDRI-1001  1.3.6.1.4.1.14519.5.2.1.6279.6001.281499745765...
# 1  LIDC-IDRI-0778  1.3.6.1.4.1.14519.5.2.1.6279.6001.174809695196...
# 2  LIDC-IDRI-0813  1.3.6.1.4.1.14519.5.2.1.6279.6001.139110171863...
# 3  LIDC-IDRI-0710  1.3.6.1.4.1.14519.5.2.1.6279.6001.116146223752...
# 4  LIDC-IDRI-0410  1.3.6.1.4.1.14519.5.2.1.6279.6001.818775038273...
#
#   Study Description             Study Date  \
# 0               NaN  2000-01-01 00:00:00.0
# 1             CHEST  2000-01-01 00:00:00.0
# 2               NaN  2000-01-01 00:00:00.0
# 3             CHEST  2000-01-01 00:00:00.0
# 4    CT LUNG SCREEN  2000-01-01 00:00:00.0
#
#                                            Series ID    Series Description  \
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...                   NaN
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100332161840...              Recon 2:
# 2  1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...                   NaN
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100530488926...  Recon 2: ACRIN LARGE
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.100620385482...                   NaN
#
#    Number of images  File Size (Bytes) Collection Name Modality  \
# 0               194          102096016       LIDC-IDRI       CT
# 1               481          253245158       LIDC-IDRI       CT
# 2               157           82630786       LIDC-IDRI       CT
# 3               471          247987448       LIDC-IDRI       CT
# 4               126           66314722       LIDC-IDRI       CT
#
#          Manufacturer
# 0             SIEMENS
# 1  GE MEDICAL SYSTEMS
# 2             SIEMENS
# 3  GE MEDICAL SYSTEMS
# 4  GE MEDICAL SYSTEMS
# ****************************************************************************************************
# 1018

# %% [markdown]
# Renomear colunas

# %%
# Renomear as colunas para 'PatientID' se necessário
nodule_counts.rename(columns={'TCIA Patent ID': 'PatientID'}, inplace=True)
patient_diagnoses.rename(columns={'TCIA Patient ID': 'PatientID'}, inplace=True)
dicom_metadata.rename(columns={'Subject ID': 'PatientID'}, inplace=True)

# %% [markdown]
# # Merge dos datasets Nodule_counts , dicom_metadata , anotações (XML)

# %%
patient_info = pd.merge( dicom_metadata,nodule_counts, on='PatientID', how='inner')
print(patient_info)



# Unificar com os metadados DICOM
complete_data = pd.merge(patient_info, patient_diagnoses, on='PatientID', how='inner')

print(complete_data.head())
# Out:
#            PatientID                                          Study UID  \
# 0     LIDC-IDRI-1001  1.3.6.1.4.1.14519.5.2.1.6279.6001.281499745765...
# 1     LIDC-IDRI-0778  1.3.6.1.4.1.14519.5.2.1.6279.6001.174809695196...
# 2     LIDC-IDRI-0813  1.3.6.1.4.1.14519.5.2.1.6279.6001.139110171863...
# 3     LIDC-IDRI-0710  1.3.6.1.4.1.14519.5.2.1.6279.6001.116146223752...
# 4     LIDC-IDRI-0410  1.3.6.1.4.1.14519.5.2.1.6279.6001.818775038273...
# ...              ...                                                ...
# 1321  LIDC-IDRI-0480  1.3.6.1.4.1.14519.5.2.1.6279.6001.167583044843...
# 1322  LIDC-IDRI-0669  1.3.6.1.4.1.14519.5.2.1.6279.6001.886430358468...
# 1323  LIDC-IDRI-0974  1.3.6.1.4.1.14519.5.2.1.6279.6001.214565862082...
# 1324  LIDC-IDRI-0473  1.3.6.1.4.1.14519.5.2.1.6279.6001.210105060472...
# 1325  LIDC-IDRI-0493  1.3.6.1.4.1.14519.5.2.1.6279.6001.333362756208...
#
#      Study Description             Study Date  \
# 0                  NaN  2000-01-01 00:00:00.0
# 1                CHEST  2000-01-01 00:00:00.0
# 2                  NaN  2000-01-01 00:00:00.0
# 3                CHEST  2000-01-01 00:00:00.0
# 4       CT LUNG SCREEN  2000-01-01 00:00:00.0
# ...                ...                    ...
# 1321               NaN  2000-01-01 00:00:00.0
# 1322               NaN  2000-01-01 00:00:00.0
# 1323               NaN  2000-01-01 00:00:00.0
# 1324  CT CHEST O CONTR  2000-01-01 00:00:00.0
# 1325             CHEST  2000-01-01 00:00:00.0
#
#                                               Series ID    Series Description  \
# 0     1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...                   NaN
# 1     1.3.6.1.4.1.14519.5.2.1.6279.6001.100332161840...              Recon 2:
# 2     1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...                   NaN
# 3     1.3.6.1.4.1.14519.5.2.1.6279.6001.100530488926...  Recon 2: ACRIN LARGE
# 4     1.3.6.1.4.1.14519.5.2.1.6279.6001.100620385482...                   NaN
# ...                                                 ...                   ...
# 1321  1.3.6.1.4.1.14519.5.2.1.6279.6001.979083010707...                   NaN
# 1322  1.3.6.1.4.1.14519.5.2.1.6279.6001.980362852713...                   NaN
# 1323  1.3.6.1.4.1.14519.5.2.1.6279.6001.991510467496...                   NaN
# 1324  1.3.6.1.4.1.14519.5.2.1.6279.6001.994459772950...                   NaN
# 1325  1.3.6.1.4.1.14519.5.2.1.6279.6001.997611074084...                   NaN
#
#       Number of images  File Size (Bytes) Collection Name Modality  \
# 0                  194          102096016       LIDC-IDRI       CT
# 1                  481          253245158       LIDC-IDRI       CT
# 2                  157           82630786       LIDC-IDRI       CT
# 3                  471          247987448       LIDC-IDRI       CT
# 4                  126           66314722       LIDC-IDRI       CT
# ...                ...                ...             ...      ...
# 1321               140           73682058       LIDC-IDRI       CT
# 1322               452          237966714       LIDC-IDRI       CT
# 1323               101           53158868       LIDC-IDRI       CT
# 1324               291          153155158       LIDC-IDRI       CT
# 1325               285          150013636       LIDC-IDRI       CT
#
#             Manufacturer  Total Number of Nodules*   \
# 0                SIEMENS                          8
# 1     GE MEDICAL SYSTEMS                          2
# 2                SIEMENS                          9
# 3     GE MEDICAL SYSTEMS                          3
# 4     GE MEDICAL SYSTEMS                          3
# ...                  ...                        ...
# 1321  GE MEDICAL SYSTEMS                         10
# 1322  GE MEDICAL SYSTEMS                          1
# 1323             SIEMENS                          6
# 1324  GE MEDICAL SYSTEMS                         14
# 1325  GE MEDICAL SYSTEMS                          2
#
#       Number of Nodules >=3mm**  Number of Nodules <3mm***  Unnamed: 4  \
# 0                             2                          6         NaN
# 1                             1                          1         NaN
# 2                             3                          6         NaN
# 3                             0                          3         NaN
# 4                             0                          3         NaN
# ...                         ...                        ...         ...
# 1321                          2                          8         NaN
# 1322                          1                          0         NaN
# 1323                          2                          4         NaN
# 1324                          4                         10         NaN
# 1325                          2                          0         NaN
#
#      Unnamed: 5
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1321        NaN
# 1322        NaN
# 1323        NaN
# 1324        NaN
# 1325        NaN
#
# [1326 rows x 16 columns]
#         PatientID                                          Study UID  \
# 0  LIDC-IDRI-1002  1.3.6.1.4.1.14519.5.2.1.6279.6001.233360976397...
# 1  LIDC-IDRI-0159  1.3.6.1.4.1.14519.5.2.1.6279.6001.150321127877...
# 2  LIDC-IDRI-0159  1.3.6.1.4.1.14519.5.2.1.6279.6001.286257039861...
# 3  LIDC-IDRI-0182  1.3.6.1.4.1.14519.5.2.1.6279.6001.254734404186...
# 4  LIDC-IDRI-0182  1.3.6.1.4.1.14519.5.2.1.6279.6001.138975273023...
#
#       Study Description             Study Date  \
# 0                   NaN  2000-01-01 00:00:00.0
# 1   CHEST, PA & LATERAL  2000-01-01 00:00:00.0
# 2              CT/C-A-P  2000-01-01 00:00:00.0
# 3  CT THORAX W/CONTRAST  2000-01-01 00:00:00.0
# 4   CHEST, PA & LATERAL  2000-01-01 00:00:00.0
#
#                                            Series ID   Series Description  \
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...                  NaN
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100678017805...  CHEST, PA & LATERAL
# 2  1.3.6.1.4.1.14519.5.2.1.6279.6001.255999614855...       Recon 2: C-A-P
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100953483028...                CHEST
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.134431569579...                Chest
#
#    Number of images  File Size (Bytes) Collection Name Modality  ...  \
# 0               321          168853494       LIDC-IDRI       CT  ...
# 1                 5           39074610       LIDC-IDRI       DX  ...
# 2               137           72138660       LIDC-IDRI       CT  ...
# 3               133           70043310       LIDC-IDRI       CT  ...
# 4                 2           15420616       LIDC-IDRI       DX  ...
#
#   Nodule 1\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                NaN
# 1                                                3.0
# 2                                                3.0
# 3                                                3.0
# 4                                                3.0
#
#    Nodule 1\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                NaN
# 1                                                4.0
# 2                                                4.0
# 3                                                4.0
# 4                                                4.0
#
#    Nodule 2\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Nodule 2\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Nodule 3\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Nodule 3\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Nodule 4\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Nodule 4\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Nodule 5\nDiagnosis at the Nodule Level \n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic)\n  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Nodule 5\nDiagnosis Method at the Nodule Level\n0 = unknown\n1 = review of radiological images to show 2 years of stable nodule\n2 = biopsy\n3 = surgical resection\n4 = progression or response\n
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 29 columns]

# %%
'''
# Criar uma lista para armazenar informações detalhadas dos contornos dos nódulos
nodule_data = []

# Obter todos os casos de Scan
cases = pl.query(pl.Scan).all()

# Acessar o décimo paciente (índice 9 porque a contagem começa em 0)
if len(cases) >= 21:
    tenth_case = cases[20]

    # Processar os nódulos do décimo paciente
    for nodule_list in tenth_case.cluster_annotations():
        print(tenth_case.patient_id)
        for nodule in nodule_list:
            print(f"Inspecting Nódulo {nodule.id}: {nodule}")
            
            for contour in nodule.contours:
                print(contour)

            # Visualizar o nódulo em 3D
            nodule.visualize_in_3d(edgecolor='green', cmap='autumn')
else:
    print("Menos de 10 pacientes disponíveis no banco de dados.")
'''
# Out:
# '\n# Criar uma lista para armazenar informações detalhadas dos contornos dos nódulos\nnodule_data = []\n\n# Obter todos os casos de Scan\ncases = pl.query(pl.Scan).all()\n\n# Acessar o décimo paciente (índice 9 porque a contagem começa em 0)\nif len(cases) >= 21:\n    tenth_case = cases[20]\n\n    # Processar os nódulos do décimo paciente\n    for nodule_list in tenth_case.cluster_annotations():\n        print(tenth_case.patient_id)\n        for nodule in nodule_list:\n            print(f"Inspecting Nódulo {nodule.id}: {nodule}")\n            \n            for contour in nodule.contours:\n                print(contour)\n\n            # Visualizar o nódulo em 3D\n            nodule.visualize_in_3d(edgecolor=\'green\', cmap=\'autumn\')\nelse:\n    print("Menos de 10 pacientes disponíveis no banco de dados.")\n'

# %% [markdown]
# # Criação do dataset com as anotações de cada nodulo

# %%
'''
np.int = np.int32  # Garantir compatibilidade com versões mais novas do NumPy

# Criar uma lista para armazenar informações detalhadas dos contornos dos nódulos
nodule_data = []

# Iterar sobre todos os casos/pacientes
cases = pl.query(pl.Scan).all()

for case in cases:
    patient_id = case.patient_id
    print(f"Processing Patient ID: {patient_id}")
    
    # Iterar sobre os nódulos do paciente
    # Iterar sobre os nódulos do paciente
    for nodule_list in case.cluster_annotations():
        if len(nodule_list) > 0:
            for nodule in nodule_list:
                print(f"Inspecting Nódulo {nodule.id}: {nodule}")
                
                # Iterar sobre os contornos do nódulo
                for contour in nodule.contours:
                    # Armazenar o ID do contorno e a posição da fatia axial (Z_Position)
                    nodule_data.append({
                        'PatientID': patient_id,
                        'NoduleID': nodule.id,
                        'ContourID': contour.id,
                        'DicomFileName': contour.dicom_file_name,
                        'Z_Position': contour.image_z_position,  # Posição da fatia axial
                        'InternalStructure': nodule.internalStructure,
                        'Sphericity': nodule.sphericity,
                        'Calcification': nodule.calcification,
                        'Subtlety': nodule.subtlety,
                        'Lobulation': nodule.lobulation,
                        'Margin': nodule.margin,
                        'Spiculation': nodule.spiculation,
                        'Texture': nodule.texture,
                        'Malignancy': nodule.malignancy
                    })
        else:
            print(f"Nódulo {nodule_list} está vazio.")

# Converter para DataFrame
nodule_df = pd.DataFrame(nodule_data)

# Exibir o DataFrame
print(nodule_df)

'''
# Out:
# '\nnp.int = np.int32  # Garantir compatibilidade com versões mais novas do NumPy\n\n# Criar uma lista para armazenar informações detalhadas dos contornos dos nódulos\nnodule_data = []\n\n# Iterar sobre todos os casos/pacientes\ncases = pl.query(pl.Scan).all()\n\nfor case in cases:\n    patient_id = case.patient_id\n    print(f"Processing Patient ID: {patient_id}")\n    \n    # Iterar sobre os nódulos do paciente\n    # Iterar sobre os nódulos do paciente\n    for nodule_list in case.cluster_annotations():\n        if len(nodule_list) > 0:\n            for nodule in nodule_list:\n                print(f"Inspecting Nódulo {nodule.id}: {nodule}")\n                \n                # Iterar sobre os contornos do nódulo\n                for contour in nodule.contours:\n                    # Armazenar o ID do contorno e a posição da fatia axial (Z_Position)\n                    nodule_data.append({\n                        \'PatientID\': patient_id,\n                        \'NoduleID\': nodule.id,\n                        \'ContourID\': contour.id,\n                        \'DicomFileName\': contour.dicom_file_name,\n                        \'Z_Position\': contour.image_z_position,  # Posição da fatia axial\n                        \'InternalStructure\': nodule.internalStructure,\n                        \'Sphericity\': nodule.sphericity,\n                        \'Calcification\': nodule.calcification,\n                        \'Subtlety\': nodule.subtlety,\n                        \'Lobulation\': nodule.lobulation,\n                        \'Margin\': nodule.margin,\n                        \'Spiculation\': nodule.spiculation,\n                        \'Texture\': nodule.texture,\n                        \'Malignancy\': nodule.malignancy\n                    })\n        else:\n            print(f"Nódulo {nodule_list} está vazio.")\n\n# Converter para DataFrame\nnodule_df = pd.DataFrame(nodule_data)\n\n# Exibir o DataFrame\nprint(nodule_df)\n\n'

# %% [markdown]
# # Transformas os dois datasets em csv

# %%
#nodule_df.to_csv('C:\\Users\\admin\\Desktop\\Laboratorios\\nodule_df.csv', index=False)
#complete_data.to_csv('C:\\Users\\gjoli\\Desktop\\UNI3\\lab\\complete_data.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3a4e2db77084> in <module>
# ----> 1 nodule_df.to_csv('C:\\Users\\admin\\Desktop\\Laboratorios\\nodule_df.csv', index=False)
#       2 #complete_data.to_csv('C:\\Users\\gjoli\\Desktop\\UNI3\\lab\\complete_data.csv', index=False)
#
# NameError: name 'nodule_df' is not defined

# %%
import os

dicom_dir = r"C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI"


def process_dicom_images(dicom_dir):
    for root, dirs, files in os.walk(dicom_dir):

        print("Root: ",root)
        print("Dirs: ",dirs)
        print("Files: ",files)

        patient_id = os.path.basename(root)
        print(f"Processing Patient ID: {patient_id}")
        
        for file in files:
            if not file.lower().endswith(".dcm"):
                print("Ainda não é imagem")
                continue
            
            dicom_path = os.path.join(root, file)
            print(f"Processing DICOM file: {dicom_path}")
            

# Executar a função de processamento
process_dicom_images(dicom_dir)
# Out:
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI
# Dirs:  ['LIDC-IDRI-0001', 'LIDC-IDRI-0002', 'LIDC-IDRI-0003', 'LIDC-IDRI-0004', 'LIDC-IDRI-0005', 'LIDC-IDRI-0006', 'LIDC-IDRI-0007', 'LIDC-IDRI-0008', 'LIDC-IDRI-0009', 'LIDC-IDRI-0010', 'LIDC-IDRI-0011', 'LIDC-IDRI-0012', 'LIDC-IDRI-0013', 'LIDC-IDRI-0014', 'LIDC-IDRI-0015', 'LIDC-IDRI-0016', 'LIDC-IDRI-0017', 'LIDC-IDRI-0018', 'LIDC-IDRI-0019', 'LIDC-IDRI-0020', 'LIDC-IDRI-0021', 'LIDC-IDRI-0022', 'LIDC-IDRI-0023', 'LIDC-IDRI-0024', 'LIDC-IDRI-0025', 'LIDC-IDRI-0026', 'LIDC-IDRI-0027', 'LIDC-IDRI-0028', 'LIDC-IDRI-0029', 'LIDC-IDRI-0030', 'LIDC-IDRI-0031', 'LIDC-IDRI-0032', 'LIDC-IDRI-0033', 'LIDC-IDRI-0034', 'LIDC-IDRI-0035', 'LIDC-IDRI-0036', 'LIDC-IDRI-0037', 'LIDC-IDRI-0038', 'LIDC-IDRI-0039', 'LIDC-IDRI-0040', 'LIDC-IDRI-0041', 'LIDC-IDRI-0042', 'LIDC-IDRI-0043', 'LIDC-IDRI-0044', 'LIDC-IDRI-0045', 'LIDC-IDRI-0046', 'LIDC-IDRI-0047', 'LIDC-IDRI-0048', 'LIDC-IDRI-0049', 'LIDC-IDRI-0050', 'LIDC-IDRI-0051', 'LIDC-IDRI-0052', 'LIDC-IDRI-0053', 'LIDC-IDRI-0054', 'LIDC-IDRI-0055', 'LIDC-IDRI-0056', 'LIDC-IDRI-0057']
# Files:  []
# Processing Patient ID: LIDC-IDRI
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001
# Dirs:  ['01-01-2000-NA-NA-30178', '01-01-2000-NA-NA-35511']
# Files:  []
# Processing Patient ID: LIDC-IDRI-0001
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178
# Dirs:  ['3000566.000000-NA-03192']
# Files:  []
# Processing Patient ID: 01-01-2000-NA-NA-30178
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192
# Dirs:  []
# Files:  ['1-001.dcm', '1-002.dcm', '1-003.dcm', '1-004.dcm', '1-005.dcm', '1-006.dcm', '1-007.dcm', '1-008.dcm', '1-009.dcm', '1-010.dcm', '1-011.dcm', '1-012.dcm', '1-013.dcm', '1-014.dcm', '1-015.dcm', '1-016.dcm', '1-017.dcm', '1-018.dcm', '1-019.dcm', '1-020.dcm', '1-021.dcm', '1-022.dcm', '1-023.dcm', '1-024.dcm', '1-025.dcm', '1-026.dcm', '1-027.dcm', '1-028.dcm', '1-029.dcm', '1-030.dcm', '1-031.dcm', '1-032.dcm', '1-033.dcm', '1-034.dcm', '1-035.dcm', '1-036.dcm', '1-037.dcm', '1-038.dcm', '1-039.dcm', '1-040.dcm', '1-041.dcm', '1-042.dcm', '1-043.dcm', '1-044.dcm', '1-045.dcm', '1-046.dcm', '1-047.dcm', '1-048.dcm', '1-049.dcm', '1-050.dcm', '1-051.dcm', '1-052.dcm', '1-053.dcm', '1-054.dcm', '1-055.dcm', '1-056.dcm', '1-057.dcm', '1-058.dcm', '1-059.dcm', '1-060.dcm', '1-061.dcm', '1-062.dcm', '1-063.dcm', '1-064.dcm', '1-065.dcm', '1-066.dcm', '1-067.dcm', '1-068.dcm', '1-069.dcm', '1-070.dcm', '1-071.dcm', '1-072.dcm', '1-073.dcm', '1-074.dcm', '1-075.dcm', '1-076.dcm', '1-077.dcm', '1-078.dcm', '1-079.dcm', '1-080.dcm', '1-081.dcm', '1-082.dcm', '1-083.dcm', '1-084.dcm', '1-085.dcm', '1-086.dcm', '1-087.dcm', '1-088.dcm', '1-089.dcm', '1-090.dcm', '1-091.dcm', '1-092.dcm', '1-093.dcm', '1-094.dcm', '1-095.dcm', '1-096.dcm', '1-097.dcm', '1-098.dcm', '1-099.dcm', '1-100.dcm', '1-101.dcm', '1-102.dcm', '1-103.dcm', '1-104.dcm', '1-105.dcm', '1-106.dcm', '1-107.dcm', '1-108.dcm', '1-109.dcm', '1-110.dcm', '1-111.dcm', '1-112.dcm', '1-113.dcm', '1-114.dcm', '1-115.dcm', '1-116.dcm', '1-117.dcm', '1-118.dcm', '1-119.dcm', '1-120.dcm', '1-121.dcm', '1-122.dcm', '1-123.dcm', '1-124.dcm', '1-125.dcm', '1-126.dcm', '1-127.dcm', '1-128.dcm', '1-129.dcm', '1-130.dcm', '1-131.dcm', '1-132.dcm', '1-133.dcm']
# Processing Patient ID: 3000566.000000-NA-03192
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-001.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-002.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-003.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-004.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-005.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-006.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-007.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-008.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-009.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-010.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-011.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-012.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-013.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-014.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-015.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-016.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-017.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-018.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-019.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-020.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-021.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-022.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-023.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-024.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-025.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-026.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-027.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-028.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-029.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-030.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-031.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-032.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-033.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-034.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-035.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-036.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-037.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-038.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-039.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-040.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-041.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-042.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-043.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-044.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-045.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-046.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-047.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-048.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-049.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-050.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-051.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-052.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-053.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-054.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-055.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-056.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-057.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-058.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-059.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-060.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-061.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-062.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-063.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-064.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-065.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-066.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-067.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-068.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-069.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-070.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-071.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-072.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-073.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-074.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-075.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-076.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-077.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-078.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-079.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-080.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-081.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-082.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-083.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-084.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-085.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-086.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-087.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-088.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-089.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-090.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-091.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-092.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-093.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-094.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-095.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-096.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-097.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-098.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-099.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-100.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-101.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-102.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-103.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-104.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-105.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-106.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-107.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-108.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-109.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-110.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-111.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-112.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-113.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-114.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-115.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-116.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-117.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-118.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-119.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-120.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-121.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-122.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-123.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-124.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-125.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-126.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-127.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-128.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-129.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-130.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-131.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-132.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-30178\3000566.000000-NA-03192\1-133.dcm
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-35511
# Dirs:  ['3000923.000000-NA-62357']
# Files:  []
# Processing Patient ID: 01-01-2000-NA-NA-35511
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-35511\3000923.000000-NA-62357
# Dirs:  []
# Files:  ['1-1.dcm', '1-2.dcm']
# Processing Patient ID: 3000923.000000-NA-62357
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-35511\3000923.000000-NA-62357\1-1.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0001\01-01-2000-NA-NA-35511\3000923.000000-NA-62357\1-2.dcm
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002
# Dirs:  ['01-01-2000-NA-NA-26851', '01-01-2000-NA-NA-98329']
# Files:  []
# Processing Patient ID: LIDC-IDRI-0002
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-26851
# Dirs:  ['3000972.000000-NA-22902']
# Files:  []
# Processing Patient ID: 01-01-2000-NA-NA-26851
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-26851\3000972.000000-NA-22902
# Dirs:  []
# Files:  ['1-1.dcm']
# Processing Patient ID: 3000972.000000-NA-22902
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-26851\3000972.000000-NA-22902\1-1.dcm
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329
# Dirs:  ['3000522.000000-NA-04919']
# Files:  []
# Processing Patient ID: 01-01-2000-NA-NA-98329
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919
# Dirs:  []
# Files:  ['1-001.dcm', '1-002.dcm', '1-003.dcm', '1-004.dcm', '1-005.dcm', '1-006.dcm', '1-007.dcm', '1-008.dcm', '1-009.dcm', '1-010.dcm', '1-011.dcm', '1-012.dcm', '1-013.dcm', '1-014.dcm', '1-015.dcm', '1-016.dcm', '1-017.dcm', '1-018.dcm', '1-019.dcm', '1-020.dcm', '1-021.dcm', '1-022.dcm', '1-023.dcm', '1-024.dcm', '1-025.dcm', '1-026.dcm', '1-027.dcm', '1-028.dcm', '1-029.dcm', '1-030.dcm', '1-031.dcm', '1-032.dcm', '1-033.dcm', '1-034.dcm', '1-035.dcm', '1-036.dcm', '1-037.dcm', '1-038.dcm', '1-039.dcm', '1-040.dcm', '1-041.dcm', '1-042.dcm', '1-043.dcm', '1-044.dcm', '1-045.dcm', '1-046.dcm', '1-047.dcm', '1-048.dcm', '1-049.dcm', '1-050.dcm', '1-051.dcm', '1-052.dcm', '1-053.dcm', '1-054.dcm', '1-055.dcm', '1-056.dcm', '1-057.dcm', '1-058.dcm', '1-059.dcm', '1-060.dcm', '1-061.dcm', '1-062.dcm', '1-063.dcm', '1-064.dcm', '1-065.dcm', '1-066.dcm', '1-067.dcm', '1-068.dcm', '1-069.dcm', '1-070.dcm', '1-071.dcm', '1-072.dcm', '1-073.dcm', '1-074.dcm', '1-075.dcm', '1-076.dcm', '1-077.dcm', '1-078.dcm', '1-079.dcm', '1-080.dcm', '1-081.dcm', '1-082.dcm', '1-083.dcm', '1-084.dcm', '1-085.dcm', '1-086.dcm', '1-087.dcm', '1-088.dcm', '1-089.dcm', '1-090.dcm', '1-091.dcm', '1-092.dcm', '1-093.dcm', '1-094.dcm', '1-095.dcm', '1-096.dcm', '1-097.dcm', '1-098.dcm', '1-099.dcm', '1-100.dcm', '1-101.dcm', '1-102.dcm', '1-103.dcm', '1-104.dcm', '1-105.dcm', '1-106.dcm', '1-107.dcm', '1-108.dcm', '1-109.dcm', '1-110.dcm', '1-111.dcm', '1-112.dcm', '1-113.dcm', '1-114.dcm', '1-115.dcm', '1-116.dcm', '1-117.dcm', '1-118.dcm', '1-119.dcm', '1-120.dcm', '1-121.dcm', '1-122.dcm', '1-123.dcm', '1-124.dcm', '1-125.dcm', '1-126.dcm', '1-127.dcm', '1-128.dcm', '1-129.dcm', '1-130.dcm', '1-131.dcm', '1-132.dcm', '1-133.dcm', '1-134.dcm', '1-135.dcm', '1-136.dcm', '1-137.dcm', '1-138.dcm', '1-139.dcm', '1-140.dcm', '1-141.dcm', '1-142.dcm', '1-143.dcm', '1-144.dcm', '1-145.dcm', '1-146.dcm', '1-147.dcm', '1-148.dcm', '1-149.dcm', '1-150.dcm', '1-151.dcm', '1-152.dcm', '1-153.dcm', '1-154.dcm', '1-155.dcm', '1-156.dcm', '1-157.dcm', '1-158.dcm', '1-159.dcm', '1-160.dcm', '1-161.dcm', '1-162.dcm', '1-163.dcm', '1-164.dcm', '1-165.dcm', '1-166.dcm', '1-167.dcm', '1-168.dcm', '1-169.dcm', '1-170.dcm', '1-171.dcm', '1-172.dcm', '1-173.dcm', '1-174.dcm', '1-175.dcm', '1-176.dcm', '1-177.dcm', '1-178.dcm', '1-179.dcm', '1-180.dcm', '1-181.dcm', '1-182.dcm', '1-183.dcm', '1-184.dcm', '1-185.dcm', '1-186.dcm', '1-187.dcm', '1-188.dcm', '1-189.dcm', '1-190.dcm', '1-191.dcm', '1-192.dcm', '1-193.dcm', '1-194.dcm', '1-195.dcm', '1-196.dcm', '1-197.dcm', '1-198.dcm', '1-199.dcm', '1-200.dcm', '1-201.dcm', '1-202.dcm', '1-203.dcm', '1-204.dcm', '1-205.dcm', '1-206.dcm', '1-207.dcm', '1-208.dcm', '1-209.dcm', '1-210.dcm', '1-211.dcm', '1-212.dcm', '1-213.dcm', '1-214.dcm', '1-215.dcm', '1-216.dcm', '1-217.dcm', '1-218.dcm', '1-219.dcm', '1-220.dcm', '1-221.dcm', '1-222.dcm', '1-223.dcm', '1-224.dcm', '1-225.dcm', '1-226.dcm', '1-227.dcm', '1-228.dcm', '1-229.dcm', '1-230.dcm', '1-231.dcm', '1-232.dcm', '1-233.dcm', '1-234.dcm', '1-235.dcm', '1-236.dcm', '1-237.dcm', '1-238.dcm', '1-239.dcm', '1-240.dcm', '1-241.dcm', '1-242.dcm', '1-243.dcm', '1-244.dcm', '1-245.dcm', '1-246.dcm', '1-247.dcm', '1-248.dcm', '1-249.dcm', '1-250.dcm', '1-251.dcm', '1-252.dcm', '1-253.dcm', '1-254.dcm', '1-255.dcm', '1-256.dcm', '1-257.dcm', '1-258.dcm', '1-259.dcm', '1-260.dcm', '1-261.dcm']
# Processing Patient ID: 3000522.000000-NA-04919
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-001.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-002.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-003.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-004.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-005.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-006.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-007.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-008.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-009.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-010.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-011.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-012.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-013.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-014.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-015.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-016.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-017.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-018.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-019.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-020.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-021.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-022.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-023.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-024.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-025.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-026.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-027.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-028.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-029.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-030.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-031.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-032.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-033.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-034.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-035.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-036.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-037.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-038.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-039.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-040.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-041.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-042.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-043.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-044.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-045.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-046.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-047.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-048.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-049.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-050.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-051.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-052.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-053.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-054.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-055.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-056.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-057.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-058.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-059.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-060.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-061.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-062.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-063.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-064.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-065.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-066.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-067.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-068.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-069.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-070.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-071.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-072.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-073.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-074.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-075.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-076.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-077.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-078.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-079.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-080.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-081.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-082.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-083.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-084.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-085.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-086.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-087.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-088.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-089.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-090.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-091.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-092.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-093.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-094.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-095.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-096.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-097.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-098.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-099.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-100.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-101.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-102.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-103.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-104.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0002\01-01-2000-NA-NA-98329\3000522.000000-NA-04919\1-105.dcm
# ...
# Processing Patient ID: 3000535.000000-NA-98069
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-001.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-002.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-003.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-004.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-005.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-006.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-007.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-008.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-009.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-010.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-011.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-012.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-013.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-014.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-015.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-016.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-017.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-018.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-019.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-020.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-021.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-022.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-023.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-024.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-025.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-026.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-027.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-028.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-029.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-030.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-031.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-032.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-033.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-034.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-035.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-036.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-037.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-038.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-039.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-040.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-041.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-042.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-043.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-044.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-045.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-046.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-047.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-048.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-049.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-050.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-051.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-052.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-053.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-054.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-055.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-056.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-057.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-058.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-059.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-060.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-061.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-062.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-063.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-064.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-065.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-066.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-067.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-068.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-069.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-070.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-071.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-072.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-073.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-074.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-075.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-076.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-077.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-078.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-079.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-080.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-081.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-082.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-083.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-084.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-085.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-086.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-087.dcm
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0056\01-01-2000-NA-NA-35375\3000535.000000-NA-98069\1-088.dcm
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0057
# Dirs:  ['01-01-2000-NA-NA-03262', '01-01-2000-NA-NA-56292']
# Files:  []
# Processing Patient ID: LIDC-IDRI-0057
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0057\01-01-2000-NA-NA-03262
# Dirs:  ['3000514.000000-NA-56951']
# Files:  []
# Processing Patient ID: 01-01-2000-NA-NA-03262
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0057\01-01-2000-NA-NA-03262\3000514.000000-NA-56951
# Dirs:  []
# Files:  ['1-001.dcm']
# Processing Patient ID: 3000514.000000-NA-56951
# Processing DICOM file: C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0057\01-01-2000-NA-NA-03262\3000514.000000-NA-56951\1-001.dcm
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0057\01-01-2000-NA-NA-56292
# Dirs:  ['3000895.000000-NA-04898']
# Files:  []
# Processing Patient ID: 01-01-2000-NA-NA-56292
# Root:  C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI\LIDC-IDRI-0057\01-01-2000-NA-NA-56292\3000895.000000-NA-04898
# Dirs:  []
# Files:  []
# Processing Patient ID: 3000895.000000-NA-04898

# %%
import os
import pydicom
import numpy as np
import matplotlib.pyplot as plt
from skimage import measure

# Diretório das imagens DICOM
dicom_dir = r"C:\Users\admin\Desktop\Laboratorios\manifest-1600709154662\LIDC-IDRI"

def convert_to_hu(dicom_img):
    # Verificar os valores do Slope e Intercept
    intercept = dicom_img.RescaleIntercept if hasattr(dicom_img, 'RescaleIntercept') else 0
    slope = dicom_img.RescaleSlope if hasattr(dicom_img, 'RescaleSlope') else 1
    
    # Aplicar a conversão para HU
    img_hu = dicom_img.pixel_array * slope + intercept
    
    # Aplicar um filtro para remover valores "fora do corpo" (HU abaixo de -1024)
    img_hu[img_hu < -1024] = -1024  # Limitar os valores a no mínimo -1024
    img_hu[img_hu > 3000] = 3000  # Limitar os valores a no mínimo -1024
    
    return img_hu


def check_hu_values(image_hu, min_hu=-1000, max_hu=3000):
    # Verificar valores mínimos e máximos
    hu_min = image_hu.min()
    hu_max = image_hu.max()
    
    # Verificar se estão fora do intervalo esperado
    #if hu_min < -1000 or hu_max > 3000:
    #    print(f"Valor HU fora do normal: HU Min = {hu_min}, HU Max = {hu_max}")
    
    # Verificar valor de um pixel específico (pixel central, por exemplo)
    central_pixel_value = image_hu[image_hu.shape[0] // 2, image_hu.shape[1] // 2]
    if central_pixel_value < -1000 or central_pixel_value > 3000:
        print(f"Valor HU no pixel central fora do normal: {central_pixel_value}")


def segment_lung_mask(image, threshold=-400):
    # Cria uma máscara binária onde o ar (HU < -400) é separado do tecido (HU > -400)
    binary_image = np.array(image > threshold, dtype=np.int8)
    return binary_image

def find_contours(image, level):
    # Detecta contornos na imagem segmentada
    contours = measure.find_contours(image, level=level)
    return contours

def load_dicom_images(dicom_dir):
    images = []
    for root, dirs, files in os.walk(dicom_dir):
        for file in files:
            if file.lower().endswith(".dcm"):
                dicom_path = os.path.join(root, file)
                dcm_image = pydicom.dcmread(dicom_path)
                images.append(dcm_image.pixel_array)
                
                print("IMAGEM ORIGINAL")
                plt.imshow(dcm_image.pixel_array, cmap='gray')
                plt.show()

                img_hu=convert_to_hu(dcm_image)
                
                #check_hu_values(img_hu)

                #print("IMAGEM NORMALIZADA")
                #plt.imshow(img_hu, cmap='gray')
                #plt.show()
                
                lung_mask = segment_lung_mask(img_hu)
                #print("PULMOES SEGMENTADOS")
                #plt.imshow(lung_mask, cmap='gray')
                #plt.show()

                #plt.figure(figsize=(12, 6))
                #plt.subplot(1, 2, 1)
                #plt.imshow(lung_mask, cmap='gray')
                #plt.title("Máscara de Segmentação dos Pulmões")
                
                lung_segmented=img_hu*lung_mask
                #plt.subplot(1, 2, 2)
                #plt.imshow(lung_segmented, cmap='gray')
                #plt.title("Pulmões Segmentados")
                #plt.show()


                #contours = find_contours(lung_mask, level=0.5)
                #print("SEGMENTO")
                #plt.imshow(img_hu, cmap='gray')
                #for contour in contours:
                #    plt.plot(contour[:, 1], contour[:, 0], linewidth=2)
                #plt.show()

    return images



images = load_dicom_images(dicom_dir)

# %%
'''
def combine_images(images):
    # Supondo que todas as imagens tenham as mesmas dimensões
    combined_image = np.stack(images, axis=-1)  # Empilha as imagens ao longo de um novo eixo
    return combined_image

# Carregar as imagens DICOM
images = load_dicom_images(dicom_dir)
print("Imagens: ",images)
# Combinar as imagens
combined_image = combine_images(images)

# Visualizar a primeira imagem da combinação
plt.imshow(combined_image[:, :, 0], cmap='gray')
plt.title("Imagem combinada - primeira fatia")
plt.axis('off')
plt.show()

# Se você quiser salvar a imagem combinada como um arquivo de imagem (ex: PNG)
plt.imsave("combined_image.png", combined_image[:, :, 0], cmap='gray')
'''

# %%
import os
import pydicom
import pylidc as pl
import pandas as pd

nodule_df = pd.read_csv('nodule_df.csv')

def load_dicom_images_and_nodules(base_dir):
    patient_data = {}  # Dicionário para armazenar imagens e nódulos

    for patient_folder in os.listdir(base_dir):
        patient_path = os.path.join(base_dir, patient_folder)
        
        # Verificar se é uma pasta
        if os.path.isdir(patient_path):
            # Armazenar o ID do paciente
            patient_id = patient_folder
            print("ID do paciente: ", patient_id)
            
            # Adicionar condição para parar até o paciente com ID 10
            if patient_id <= "LIDC-IDRI-0010":
                # Carregar as imagens DICOM
                images = []
                for root, dirs, files in os.walk(patient_path):
                    for file in files:
                        if file.lower().endswith(".dcm"):
                            dicom_path = os.path.join(root, file)
                            dcm_image = pydicom.dcmread(dicom_path)
                            images.append(dcm_image.pixel_array)
                
                # Armazenar as imagens e nódulos no dicionário
                patient_data[patient_id] = {
                    "images": images,
                    "nodules": nodule_df[nodule_df['PatientID'] == patient_id]  # Acessar os nódulos do paciente
                }
            else:
                print(f"Parando a execução após o paciente: {patient_id}")
                break
    
    return patient_data

# Usar a função
base_dir = "C:\\Users\\admin\\Desktop\\Laboratorios\\manifest-1600709154662\\LIDC-IDRI"
patient_data = load_dicom_images_and_nodules(base_dir)

# Exibir informações sobre os pacientes carregados
for patient_id, data in patient_data.items():
    print(f"Patient ID: {patient_id}")
    print(f"Número de imagens: {len(data['images'])}")
    print(f"Nódulos encontrados: {[nodule['NoduleID'] for _, nodule in data['nodules'].iterrows()]}")
# Out:
# ID do paciente:  LIDC-IDRI-0001
# ID do paciente:  LIDC-IDRI-0002
# ID do paciente:  LIDC-IDRI-0003
# ID do paciente:  LIDC-IDRI-0004
# ID do paciente:  LIDC-IDRI-0005
# ID do paciente:  LIDC-IDRI-0006
# ID do paciente:  LIDC-IDRI-0007
# ID do paciente:  LIDC-IDRI-0008
# ID do paciente:  LIDC-IDRI-0009
# ID do paciente:  LIDC-IDRI-0010
# ID do paciente:  LIDC-IDRI-0011
# Parando a execução após o paciente: LIDC-IDRI-0011
# Patient ID: LIDC-IDRI-0001
# Número de imagens: 135
# Nódulos encontrados: [84, 84, 84, 84, 84, 84, 84, 84, 85, 85, 85, 85, 85, 85, 85, 86, 86, 86, 86, 86, 86, 86, 86, 87, 87, 87, 87, 87, 87, 87, 87, 87]
# Patient ID: LIDC-IDRI-0002
# Número de imagens: 262
# Nódulos encontrados: [88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 88, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89, 89]
# Patient ID: LIDC-IDRI-0003
# Número de imagens: 145
# Nódulos encontrados: [102, 102, 102, 102, 102, 102, 102, 102, 90, 90, 90, 90, 90, 90, 90, 93, 93, 93, 93, 93, 93, 93, 98, 98, 98, 98, 98, 98, 98, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 91, 91, 91, 91, 95, 95, 97, 97, 97, 97, 100, 100, 100, 100, 92, 92, 92, 92, 92, 94, 94, 94, 94, 94, 96, 96, 96, 96, 96, 101, 101, 101, 101, 101, 101, 101, 101]
# Patient ID: LIDC-IDRI-0004
# Número de imagens: 242
# Nódulos encontrados: [103, 103, 103, 103, 104, 104, 104, 105, 105, 105, 105, 106, 106, 106, 106, 106]
# Patient ID: LIDC-IDRI-0005
# Número de imagens: 135
# Nódulos encontrados: [107, 107, 110, 110, 113, 113, 114, 114, 108, 108, 108, 111, 112, 112, 115, 115, 115, 109, 109]
# Patient ID: LIDC-IDRI-0006
# Número de imagens: 135
# Nódulos encontrados: [116, 116, 119, 121, 123, 123, 123, 123, 117, 117, 118, 118, 120, 120, 120, 122, 122, 122]
# Patient ID: LIDC-IDRI-0007
# Número de imagens: 149
# Nódulos encontrados: [124, 124, 124, 124, 124, 124, 124, 124, 124, 124, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 127, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 125, 125, 125, 125, 125, 125, 125, 125, 125, 125, 125, 125]
# Patient ID: LIDC-IDRI-0008
# Número de imagens: 135
# Nódulos encontrados: [129, 129, 131, 131, 134, 134, 130, 130, 132, 132, 133, 133, 135, 135, 135]
# Patient ID: LIDC-IDRI-0009
# Número de imagens: 257
# Nódulos encontrados: [136, 136, 136, 137, 137, 137, 137]
# Patient ID: LIDC-IDRI-0010
# Número de imagens: 278
# Nódulos encontrados: [144, 144, 144, 144, 141, 141, 141, 141, 143, 143, 143, 143, 143, 138, 138, 138, 138, 139, 139, 139, 139, 140, 140, 140, 140, 142, 142, 142, 142, 142, 142]

# %%
import pylidc as pl

def get_nodule_coordinates(patient_id):
    # Carregar o scan do paciente
    scan = pl.query(pl.Scan).filter(pl.Scan.patient_id == patient_id).first()
    
    if scan is None:
        print(f"Nenhum scan encontrado para o paciente {patient_id}")
        return None
    
    # Obter as anotações dos nódulos
    annotations = scan.annotations
    
    # Percorrer cada nódulo anotado
    for i, annotation in enumerate(annotations):
        #print(f"Paciente {i + 1}:")
        #print(f"  Nodule ID: {annotation.id}")
        #print(f"  Coordenadas das fatias (slices): {annotation.contour_points}")

        contours = annotation.contours
        for contour in contours:
            #print(contour)
            coordinates = contour.to_matrix()
            #print(f"Coordinates (x, y, z) for Contour {contour.id}:")
            #print(coordinates)
    
    return coordinates

# Exemplo de uso
patient_id = "LIDC-IDRI-0001"  # Substitua pelo ID do paciente que você quer analisar
annotations = get_nodule_coordinates(patient_id)

# %%
import numpy as np
import matplotlib.pyplot as plt

def isolate_nodule_with_coordinates(pixel_array, coordinates):
    # Criar uma máscara vazia com o mesmo tamanho da imagem
    mask = np.zeros(pixel_array.shape, dtype=np.uint8)
    
    #print("MASK: ",mask)

    # Preencher a máscara com 1 nas coordenadas fornecidas
    for coord in coordinates:
        #print("Coord: ",coord)
        x, y, z = map(int, coord)  # Converter para inteiros
        mask[y, x] = 1  # Aplicar máscara nas coordenadas (x, y)

    # Aplicar a máscara à imagem original, isolando o nódulo
    isolated_nodule = np.where(mask == 1, pixel_array, 0)

    return isolated_nodule

'''
# Exemplo de uso da função
# Vamos supor que 'pixel_array' é a imagem e 'coordinates' são as coordenadas fornecidas

# Aqui 'pixel_array' seria a tua imagem DICOM carregada
# coordinates seria o array de coordenadas que mencionaste
isolated_nodule = isolate_nodule_with_coordinates(pixel_array, coordinates)

# Visualizar o nódulo isolado
plt.imshow(isolated_nodule, cmap='gray')
plt.title("Nódulo Isolado")
plt.show()
'''
# Out:
# '\n# Exemplo de uso da função\n# Vamos supor que \'pixel_array\' é a imagem e \'coordinates\' são as coordenadas fornecidas\n\n# Aqui \'pixel_array\' seria a tua imagem DICOM carregada\n# coordinates seria o array de coordenadas que mencionaste\nisolated_nodule = isolate_nodule_with_coordinates(pixel_array, coordinates)\n\n# Visualizar o nódulo isolado\nplt.imshow(isolated_nodule, cmap=\'gray\')\nplt.title("Nódulo Isolado")\nplt.show()\n'

# %%
import pandas as pd
import pydicom
import os
import matplotlib.pyplot as plt

# Carregar o dataset
nodule_df = pd.read_csv('nodule_df.csv')

# Função para carregar e isolar nódulos
def isolate_nodules(base_dir, nodule_df):
    for _, row in nodule_df.iterrows():
        patient_id = row['PatientID']
        
        # Verificar se o ID do paciente é menor ou igual a 57 (É so porque nao tenho as imagens todas)
        if int(patient_id.split('-')[-1]) > 57:  # Extrai o número do ID
            continue  # Ignora pacientes com ID maior que 57
        
        dicom_file = row['DicomFileName']
        #print(dicom_file)
        contour_id = row['ContourID']
        
        # Localizar a pasta do paciente
        patient_folder = os.path.join(base_dir, patient_id)
        
        modified_dicom_file = f'1-{dicom_file}'

        # Percorrer as subpastas para encontrar o arquivo DICOM
        for root, dirs, files in os.walk(patient_folder):
            
            #print("Root: ",root)
            #print("Dirs: ",dirs)
            #print("Files: ",files)


            if modified_dicom_file in files:  # Verifica se o arquivo está nesta pasta
                dicom_path = os.path.join(root, modified_dicom_file)
                
                # Ler a imagem DICOM
                dcm_image = pydicom.dcmread(dicom_path)
                pixel_array = dcm_image.pixel_array
                
                # Aqui você deve obter as coordenadas do nódulo usando o ContourID
                coordinates=get_nodule_coordinates(patient_id)
                
                # Isolar o nódulo usando as coordenadas
                #print(coordinates)
                isolated_nodule = isolate_nodule_with_coordinates(pixel_array, coordinates)

                # Visualizar o nódulo isolado
                plt.imshow(isolated_nodule, cmap='gray')
                plt.title("Nódulo Isolado")
                plt.show()
                
                # Visualizar ou armazenar a imagem com o nódulo isolado
                #print(f'Processed DICOM: {dicom_path}')
                #plt.imshow(dcm_image.pixel_array, cmap='gray')
                #plt.show()
                break  # Interrompe o loop após encontrar o arquivo

# Usar a função
base_dir = "C:\\Users\\admin\\Desktop\\Laboratorios\\manifest-1600709154662\\LIDC-IDRI"
isolate_nodules(base_dir, nodule_df)
# Out:
# Error closing cursor
# Traceback (most recent call last):
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\result.py", line 1813, in _fetchall_impl
#     return list(self.iterator)
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\orm\loading.py", line 147, in chunks
#     fetch = cursor._raw_all_rows()
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\result.py", line 392, in _raw_all_rows
#     rows = self._fetchall_impl()
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\cursor.py", line 1819, in _fetchall_impl
#     return self.cursor_strategy.fetchall(self, self.cursor)
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\cursor.py", line 995, in fetchall
#     self.handle_exception(result, dbapi_cursor, e)
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\cursor.py", line 956, in handle_exception
#     err, None, None, dbapi_cursor, result.context
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\base.py", line 2138, in _handle_dbapi_exception
#     util.raise_(exc_info[1], with_traceback=exc_info[2])
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\util\compat.py", line 211, in raise_
#     raise exception
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\cursor.py", line 991, in fetchall
#     rows = dbapi_cursor.fetchall()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\base.py", line 2005, in _safe_close_cursor
#     cursor.close()
# sqlite3.ProgrammingError: Cannot operate on a closed database.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-d21f9812aebe> in <module>
#      60 # Usar a função
#      61 base_dir = "C:\\Users\\admin\\Desktop\\Laboratorios\\manifest-1600709154662\\LIDC-IDRI"
# ---> 62 isolate_nodules(base_dir, nodule_df)
#
# <ipython-input-62-d21f9812aebe> in isolate_nodules(base_dir, nodule_df)
#      41
#      42                 # Aqui você deve obter as coordenadas do nódulo usando o ContourID
# ---> 43                 coordinates=get_nodule_coordinates(patient_id)
#      44
#      45                 # Isolar o nódulo usando as coordenadas
#
# <ipython-input-57-f90e51d18b9d> in get_nodule_coordinates(patient_id)
#      18         #print(f"  Coordenadas das fatias (slices): {annotation.contour_points}")
#      19
# ---> 20         contours = annotation.contours
#      21         for contour in contours:
#      22             #print(contour)
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\orm\attributes.py in __get__(self, instance, owner)
#     485                     replace_context=err,
#     486                 )
# --> 487             return self.impl.get(state, dict_)
#     488
#     489
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\orm\attributes.py in get(self, state, dict_, passive)
#     957                     return PASSIVE_NO_RESULT
#     958
# --> 959                 value = self._fire_loader_callables(state, key, passive)
#     960
#     961                 if value is PASSIVE_NO_RESULT or value is NO_VALUE:
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\orm\attributes.py in _fire_loader_callables(self, state, key, passive)
#     993             return callable_(state, passive)
#     994         elif self.callable_:
# --> 995             return self.callable_(state, passive)
#     996         else:
#     997             return ATTR_EMPTY
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\orm\strategies.py in _load_for_state(self, state, passive, loadopt, extra_criteria)
#     916             passive,
#     917             loadopt,
# --> 918             extra_criteria,
#     919         )
#     920
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\orm\strategies.py in _emit_lazyload(self, session, state, primary_key_identity, passive, loadopt, extra_criteria)
#    1048         )
#    1049
# -> 1050         result = result.unique().scalars().all()
#    1051
#    1052         if self.uselist:
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\result.py in all(self)
#    1474
#    1475         """
# -> 1476         return self._allrows()
#    1477
#    1478     def __iter__(self):
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\result.py in _allrows(self)
#     399         make_row = self._row_getter
#     400
# --> 401         rows = self._fetchall_impl()
#     402         if make_row:
#     403             made_rows = [make_row(row) for row in rows]
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\result.py in _fetchall_impl(self)
#    1387
#    1388     def _fetchall_impl(self):
# -> 1389         return self._real_result._fetchall_impl()
#    1390
#    1391     def _fetchmany_impl(self, size=None):
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\result.py in _fetchall_impl(self)
#    1811
#    1812         try:
# -> 1813             return list(self.iterator)
#    1814         finally:
#    1815             self._soft_close()
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\orm\loading.py in chunks(size)
#     145                     break
#     146             else:
# --> 147                 fetch = cursor._raw_all_rows()
#     148
#     149             if single_entity:
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\result.py in _raw_all_rows(self)
#     390     def _raw_all_rows(self):
#     391         make_row = self._row_getter
# --> 392         rows = self._fetchall_impl()
#     393         return [make_row(row) for row in rows]
#     394
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\cursor.py in _fetchall_impl(self)
#    1817
#    1818     def _fetchall_impl(self):
# -> 1819         return self.cursor_strategy.fetchall(self, self.cursor)
#    1820
#    1821     def _fetchmany_impl(self, size=None):
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\cursor.py in fetchall(self, result, dbapi_cursor)
#     993             return rows
#     994         except BaseException as e:
# --> 995             self.handle_exception(result, dbapi_cursor, e)
#     996
#     997
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\cursor.py in handle_exception(self, result, dbapi_cursor, err)
#     954     def handle_exception(self, result, dbapi_cursor, err):
#     955         result.connection._handle_dbapi_exception(
# --> 956             err, None, None, dbapi_cursor, result.context
#     957         )
#     958
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2136                 )
#    2137             else:
# -> 2138                 util.raise_(exc_info[1], with_traceback=exc_info[2])
#    2139
#    2140         finally:
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# c:\Users\admin\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\engine\cursor.py in fetchall(self, result, dbapi_cursor)
#     989     def fetchall(self, result, dbapi_cursor):
#     990         try:
# --> 991             rows = dbapi_cursor.fetchall()
#     992             result._soft_close()
#     993             return rows
#
# KeyboardInterrupt:
